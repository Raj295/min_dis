# %%
import os
import sys
sys.path.append(os.path.abspath("C:/Users/Raj/Desktop/Peter/GGab.py"))
sys.path.append(os.path.abspath("C:/Users/Raj/Desktop/Peter/GGab1.py"))
import numpy as np
from GGab import *
from GGab1 import *
from haversine import haversine, Unit
import pandas as pd

my_new_list = []
for i in list1:
    p1=(i)
  
    my_new_list = []
    for r in list2:
            p2=(r)
            df1= haversine(p1, p2, unit=Unit.MILES)
            print(df1)
# Out:
# 235.4062044509653
# 294.3383882781176
# 360.8126010954147
# 243.46535300848493
# 98.76157428171943
# 243.37326606151012
# 25.249676743615122
# 339.8999987702447
# 278.6930534351172
# 293.67077520132693
# 455.1208255020419
# 92.00321266301172
# 416.33607139223545
# 326.1129137538948
# 342.5423483653572
# 238.80488938687975
# 222.94248664957766
# 234.23322734418818
# 347.48902819941327
# 328.1732970442045
# 205.0437661249292
# 530.823503779529
# 64.9009362393612
# 289.9703853294975
# 388.7642887907351
# 185.05833842243933
# 245.79527074251243
# 303.3817809487885
# 312.7941192831136
# 380.639476665349
# 502.4290141124839
# 338.492764251111
# 259.38099541329944
# 362.0999287961894
# 282.6923799586044
# 246.32602021063593
# 350.1150183812694
# 242.06836244066562
# 327.94631250224325
# 388.1949128271075
# 454.1473701451278
# 143.65674252482373
# 53.28554257899586
# 212.73008338721894
# 284.6440363745446
# 324.74466138712256
# 197.05319730914928
# 476.2573513744998
# 473.9993304957166
# ...
